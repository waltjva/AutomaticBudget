# %%
import bank_functions_NWFCU as nw
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
prime_df = pd.read_excel('../data/fully_catized_encoded_3.xlsx')
prime_df.columns
# Out:
# Index(['Purchase Date', 'Purchase Time', 'Payment_Method', 'Amount', 'Verification Date', 'Content', 'Category', 'VD_year', 'PT_total_seconds', 'sin_PT_total_seconds', 'cos_PT_total_seconds', 'PD_year', 'sin_PD_month', 'cos_PD_month', 'sin_PD_day', 'cos_PD_day', 'sin_VD_month', 'cos_VD_month', 'sin_VD_day', 'cos_VD_day', 'Payment_Method_Cat', 0, 1, 2, 3, 'Category_Cat'], dtype='object')

# %%
may_df = pd.read_excel('../data/May_21_I_tried.xlsx')
june_df = pd.read_excel('../data/June_21_I_tried.xlsx')
july_df = pd.read_excel('../data/July_21_I_tried.xlsx')
jul_df = pd.read_excel('../data/July_21_I_tried_NWFCU.xlsx')
aug_df = pd.read_excel('../data/August_21_I_tried_NWFCU.xlsx')

# %%
aug_df.columns == jul_df.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
len(jul_df) + len(aug_df)
# Out:
# 52

# %%
# pd concat on the Atlantic Union bank statements, may_df, june_df, july_df
au_df = pd.concat([may_df,june_df,july_df]).reset_index(drop=True)
au_df
# Out:
#     Purchase Date                                                          Content   Amount                  Category         Payment_Method Purchase Time Verification Date  PD_year  sin_PD_month  cos_PD_month  ...  VD_year  sin_VD_month  cos_VD_month  sin_VD_day  cos_VD_day  Payment_Method_Cat  0  1  2  3
# 0      2021-05-27                              VENMO/PAYMENTWALTER COLEMAN Default   -25.00                   Default                  VENMO      00:00:00        2021-05-27     2021  5.000000e-01     -0.866025  ...     2021  5.000000e-01     -0.866025   -0.724793    0.688967         Placeholder  0  0  0  1
# 1      2021-05-24                              VENMO/CASHOUTWALTER COLEMAN Default    64.00               Venmo Extra                  VENMO      00:00:00        2021-05-24     2021  5.000000e-01     -0.866025  ...     2021  5.000000e-01     -0.866025   -0.988468    0.151428         Placeholder  0  0  0  1
# ...

# %%
# pd concat on the NWFCU bank statements, jul_df, aug_df
nw_df = pd.concat([jul_df,aug_df]).reset_index(drop=True)
nw_df
# Out:
#    Purchase Date Purchase Time Payment_Method   Amount Verification Date                                                                                           Content                  Category  Category_Pred            Cat_Pred_Words             Cat_Self_Pred  ...  sin_VD_month  cos_VD_month    sin_VD_day  cos_VD_day  Payment_Method_Cat  0  1  2  3  eff_date_month
# 0     2021-07-30      00:00:00     Debit Card   -13.35        2021-07-30                                               White Spot CKE*THE WHITE SPOT ATLAATLANTA      GAUS                   Default              7                      Misc                Dining Out  ...     -0.500000     -0.866025 -2.012985e-01    0.979530                   1  1  0  0  0               7
# ...

# %%
[x for x in prime_df.columns if x not in au_df.columns]
# Out:
# ['Category_Cat']

# %%
prime_df
# Out:
#     Purchase Date Purchase Time         Payment_Method   Amount Verification Date                                                              Content                  Category  VD_year  PT_total_seconds  sin_PT_total_seconds  ...  sin_VD_month  cos_VD_month    sin_VD_day  cos_VD_day  Payment_Method_Cat  0  1  2  3  Category_Cat
# 0      2021-01-29      00:00:00                  Other  -187.68        2021-01-29                                USAA PC/PAYMENTWALTER COLEMAN Default            USAA Insurance     2021                 0          0.000000e+00  ...  5.000000e-01  8.660254e-01 -3.943559e-01    0.918958                   0  1  0  0  0            14
# 1      2021-01-27      00:00:00                  VENMO   669.80        2021-01-27                                  VENMO/CASHOUTWALTER COLEMAN Default               Venmo Extra     2021                 0          0.000000e+00  ...  5.000000e-01  8.660254e-01 -7.247928e-01    0.688967                   3  0  0  0  1            16
# ...

# %%
[x for x in au_df.columns if x not in prime_df.columns]
# Out:
# []

# %%
[x for x in nw_df.columns if x not in prime_df.columns]
# Out:
# ['Category_Pred',
#  'Cat_Pred_Words',
#  'Cat_Self_Pred',
#  'Self_Pred_Nums',
#  'eff_date_month']

# %%
[x for x in nw_df.columns if x not in au_df.columns]
# Out:
# ['Category_Pred',
#  'Cat_Pred_Words',
#  'Cat_Self_Pred',
#  'Self_Pred_Nums',
#  'eff_date_month']

# %%
# fully categorized and encoded
prime_df = pd.read_excel('../data/fully_catized_encoded_3.xlsx')
 # tuple
# print("ref_n2w: ", ref[0], "ref_w2n: ", ref[1])
# formats data from raw csv from Atlantic Union website
may_df = bf.clean_bank_statement_file('../data/May21Checking.csv')
may_df = bf.encode_data(may_df)
may_df['Category_Pred'] = bf.decision_tree_new_statements(prime_df, may_df)
may_df['Cat_Self_Pred'] = bf.self_categorization(may_df, ref)

# %%
ref = nw.ref_dictionaries(prime_df)

# %%
nw_df['Category_Cat'] = nw_df['Cat_Self_Pred'].apply(lambda x: ref[0][x])
nw_df['Category'] = nw_df['Cat_Self_Pred'].copy()

# %%
from sklearn.metrics import mean_squared_error
y_true = au_df['Category_Cat']
mean_squared_error(y_true, y_pred)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Category_Cat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-aad64552aa1e> in <module>
# ...

# %%
['Category_Pred',
 'Cat_Pred_Words',
 'Cat_Self_Pred',
 'Self_Pred_Nums',
 'eff_date_month']

# %%
prime_df.columns
# Out:
# Index(['Purchase Date', 'Purchase Time', 'Payment_Method', 'Amount', 'Verification Date', 'Content', 'Category', 'VD_year', 'PT_total_seconds', 'sin_PT_total_seconds', 'cos_PT_total_seconds', 'PD_year', 'sin_PD_month', 'cos_PD_month', 'sin_PD_day', 'cos_PD_day', 'sin_VD_month', 'cos_VD_month', 'sin_VD_day', 'cos_VD_day', 'Payment_Method_Cat', 0, 1, 2, 3, 'Category_Cat'], dtype='object')

# %%
nw_df = nw_df[['Purchase Date', 'Purchase Time', 'Payment_Method', 'Amount', 'Verification Date', 'Content', 'Category', 'VD_year', 'PT_total_seconds', 'sin_PT_total_seconds', 'cos_PT_total_seconds', 'PD_year', 'sin_PD_month', 'cos_PD_month', 'sin_PD_day', 'cos_PD_day', 'sin_VD_month', 'cos_VD_month', 'sin_VD_day', 'cos_VD_day', 'Payment_Method_Cat', 0, 1, 2, 3, 'Category_Cat']].copy()

# %%
prime_df = pd.concat([prime_df,nw_df]).reset_index(drop=True)

# %%
# now to categorize the au_df categories

# %%
au_df
# Out:
#     Purchase Date                                                          Content   Amount                  Category         Payment_Method Purchase Time Verification Date  PD_year  sin_PD_month  cos_PD_month  ...  VD_year  sin_VD_month  cos_VD_month  sin_VD_day  cos_VD_day  Payment_Method_Cat  0  1  2  3
# 0      2021-05-27                              VENMO/PAYMENTWALTER COLEMAN Default   -25.00                   Default                  VENMO      00:00:00        2021-05-27     2021  5.000000e-01     -0.866025  ...     2021  5.000000e-01     -0.866025   -0.724793    0.688967         Placeholder  0  0  0  1
# 1      2021-05-24                              VENMO/CASHOUTWALTER COLEMAN Default    64.00               Venmo Extra                  VENMO      00:00:00        2021-05-24     2021  5.000000e-01     -0.866025  ...     2021  5.000000e-01     -0.866025   -0.988468    0.151428         Placeholder  0  0  0  1
# ...

# %%
import bank_functions as bf

# %%
may_df['Category_Pred'] = bf.decision_tree_new_statements(prime_df, au_df)
may_df['Cat_Self_Pred'] = bf.self_categorization(au_df, ref)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-c112b52641a3> in <module>
# ----> 1 may_df['Category_Pred'] = bf.decision_tree_new_statements(prime_df, au_df)
#       2 may_df['Cat_Self_Pred'] = bf.self_categorization(au_df, ref)
#
# ~/Documents/BankStatementCategorizer/BankParser/Code/bank_functions.py in decision_tree_new_statements(df, new_df)
#     129     """
#     130     X = df.drop(['Purchase Date','Purchase Time','Payment_Method','Verification Date', 'Content','Category','PT_total_seconds','Payment_Method_Cat', 'Category_Cat'], axis=1)
# --> 131     new_X = new_df.drop(['Purchase Date','Purchase Time','Payment_Method','Verification Date',\
#     132                          'Content', 'Category','PT_total_seconds','Payment_Method_Cat'], axis=1)
#     133     y = df['Category_Cat'].copy()
#
# ...

# %%
prime_df.to_excel('../data/fully_catized_encoded.xlsx',index=False)

# %%
au_df.to_excel('../data/atlantic_union_df.xlsx',index=False)
