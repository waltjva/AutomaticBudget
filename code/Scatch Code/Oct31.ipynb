# %%
import pandas as pd

# %%
oct_df = pd.read_csv('OctoberChecking.csv')

# %%
oct_df
# Out:
#                           Account Name : Fox Checking  Unnamed: 1  \
# 0                 Account Number : 229753847K63032206         NaN
# 1                  Date Range : 10/01/2020-10/31/2020         NaN
# 2                                  Transaction Number        Date
# 3   20201030000000[-5:EST]*-500.00*13**POS PURCHAS...  10/30/2020
# 4   20201030000000[-5:EST]*-5.13*13**POS PURCHASE ...  10/30/2020
# ..                                                ...         ...
# 79  20201005000000[-5:EST]*-6.60*42**POS PURCHASE ...   10/5/2020
# 80  20201005000000[-5:EST]*-14.47*42**POS PURCHASE...   10/5/2020
# 81  20201005000000[-5:EST]*-4.74*13**POS PURCHASE ...   10/5/2020
# 82  20201005000000[-5:EST]*147.33*512**INTERNET TR...   10/5/2020
# 83     20201002000000[-5:EST]*-10.48*42**POS PURCHASE   10/2/2020
#
#                          Unnamed: 2  \
# 0                               NaN
# 1                               NaN
# 2                       Description
# ...

# %%
oct_df.loc[2]
# Out:
# Account Name : Fox Checking    Transaction Number
# Unnamed: 1                                   Date
# Unnamed: 2                            Description
# Unnamed: 3                                   Memo
# Unnamed: 4                           Amount Debit
# Unnamed: 5                          Amount Credit
# Unnamed: 6                                Balance
# Unnamed: 7                           Check Number
# Unnamed: 8                                 Fees
# Name: 2, dtype: object

# %%
oct_df.columns = oct_df.loc[2]

# %%
oct_df.drop([0,1],inplace=True)

# %%
oct_df
# Out:
# 2                                  Transaction Number        Date  \
# 2                                  Transaction Number        Date
# 3   20201030000000[-5:EST]*-500.00*13**POS PURCHAS...  10/30/2020
# 4   20201030000000[-5:EST]*-5.13*13**POS PURCHASE ...  10/30/2020
# 5      20201029000000[-5:EST]*-31.10*42**POS PURCHASE  10/29/2020
# 6   20201029000000[-5:EST]*-47.56*13**POS PURCHASE...  10/29/2020
# ..                                                ...         ...
# 79  20201005000000[-5:EST]*-6.60*42**POS PURCHASE ...   10/5/2020
# 80  20201005000000[-5:EST]*-14.47*42**POS PURCHASE...   10/5/2020
# 81  20201005000000[-5:EST]*-4.74*13**POS PURCHASE ...   10/5/2020
# 82  20201005000000[-5:EST]*147.33*512**INTERNET TR...   10/5/2020
# 83     20201002000000[-5:EST]*-10.48*42**POS PURCHASE   10/2/2020
#
# 2                       Description  \
# 2                       Description
# 3      POS PURCHASE with PINCALIBER
# 4   POS PURCHASE with PINGIANT 0774
# ...

# %%
oct_df.drop([2],inplace=True)

# %%
oct_df.drop(['Check Number'],axis=1,inplace=True)

# %%
oct_df
# Out:
# 2                                  Transaction Number        Date  \
# 3   20201030000000[-5:EST]*-500.00*13**POS PURCHAS...  10/30/2020
# 4   20201030000000[-5:EST]*-5.13*13**POS PURCHASE ...  10/30/2020
# 5      20201029000000[-5:EST]*-31.10*42**POS PURCHASE  10/29/2020
# 6   20201029000000[-5:EST]*-47.56*13**POS PURCHASE...  10/29/2020
# 7   20201028000000[-5:EST]*-9.34*42**POS PURCHASE ...  10/28/2020
# ..                                                ...         ...
# 79  20201005000000[-5:EST]*-6.60*42**POS PURCHASE ...   10/5/2020
# 80  20201005000000[-5:EST]*-14.47*42**POS PURCHASE...   10/5/2020
# 81  20201005000000[-5:EST]*-4.74*13**POS PURCHASE ...   10/5/2020
# 82  20201005000000[-5:EST]*147.33*512**INTERNET TR...   10/5/2020
# 83     20201002000000[-5:EST]*-10.48*42**POS PURCHASE   10/2/2020
#
# 2                       Description  \
# 3      POS PURCHASE with PINCALIBER
# 4   POS PURCHASE with PINGIANT 0774
# 5                      POS PURCHASE
# ...

# %%
oct_df.drop(['Fees  '],axis=1,inplace=True)

# %%
oct_df
# Out:
# 2                                  Transaction Number        Date  \
# 3   20201030000000[-5:EST]*-500.00*13**POS PURCHAS...  10/30/2020
# 4   20201030000000[-5:EST]*-5.13*13**POS PURCHASE ...  10/30/2020
# 5      20201029000000[-5:EST]*-31.10*42**POS PURCHASE  10/29/2020
# 6   20201029000000[-5:EST]*-47.56*13**POS PURCHASE...  10/29/2020
# 7   20201028000000[-5:EST]*-9.34*42**POS PURCHASE ...  10/28/2020
# ..                                                ...         ...
# 79  20201005000000[-5:EST]*-6.60*42**POS PURCHASE ...   10/5/2020
# 80  20201005000000[-5:EST]*-14.47*42**POS PURCHASE...   10/5/2020
# 81  20201005000000[-5:EST]*-4.74*13**POS PURCHASE ...   10/5/2020
# 82  20201005000000[-5:EST]*147.33*512**INTERNET TR...   10/5/2020
# 83     20201002000000[-5:EST]*-10.48*42**POS PURCHASE   10/2/2020
#
# 2                       Description  \
# 3      POS PURCHASE with PINCALIBER
# 4   POS PURCHASE with PINGIANT 0774
# 5                      POS PURCHASE
# ...

# %%
oct_df.drop(['Balance'],axis=1,inplace=True)

# %%
oct_df
# Out:
# 2                                  Transaction Number        Date  \
# 3   20201030000000[-5:EST]*-500.00*13**POS PURCHAS...  10/30/2020
# 4   20201030000000[-5:EST]*-5.13*13**POS PURCHASE ...  10/30/2020
# 5      20201029000000[-5:EST]*-31.10*42**POS PURCHASE  10/29/2020
# 6   20201029000000[-5:EST]*-47.56*13**POS PURCHASE...  10/29/2020
# 7   20201028000000[-5:EST]*-9.34*42**POS PURCHASE ...  10/28/2020
# ..                                                ...         ...
# 79  20201005000000[-5:EST]*-6.60*42**POS PURCHASE ...   10/5/2020
# 80  20201005000000[-5:EST]*-14.47*42**POS PURCHASE...   10/5/2020
# 81  20201005000000[-5:EST]*-4.74*13**POS PURCHASE ...   10/5/2020
# 82  20201005000000[-5:EST]*147.33*512**INTERNET TR...   10/5/2020
# 83     20201002000000[-5:EST]*-10.48*42**POS PURCHASE   10/2/2020
#
# 2                       Description  \
# 3      POS PURCHASE with PINCALIBER
# 4   POS PURCHASE with PINGIANT 0774
# 5                      POS PURCHASE
# ...

# %%
oct_df.drop(oct_df.loc[oct_df['Description'] == 'INTERNET TRANSFER FROM:'].index)
# Out:
# 2                                  Transaction Number        Date  \
# 3   20201030000000[-5:EST]*-500.00*13**POS PURCHAS...  10/30/2020
# 4   20201030000000[-5:EST]*-5.13*13**POS PURCHASE ...  10/30/2020
# 5      20201029000000[-5:EST]*-31.10*42**POS PURCHASE  10/29/2020
# 6   20201029000000[-5:EST]*-47.56*13**POS PURCHASE...  10/29/2020
# 7   20201028000000[-5:EST]*-9.34*42**POS PURCHASE ...  10/28/2020
# ..                                                ...         ...
# 78  20201005000000[-5:EST]*-2.28*42**POS PURCHASE ...   10/5/2020
# 79  20201005000000[-5:EST]*-6.60*42**POS PURCHASE ...   10/5/2020
# 80  20201005000000[-5:EST]*-14.47*42**POS PURCHASE...   10/5/2020
# 81  20201005000000[-5:EST]*-4.74*13**POS PURCHASE ...   10/5/2020
# 83     20201002000000[-5:EST]*-10.48*42**POS PURCHASE   10/2/2020
#
# 2                       Description  \
# 3      POS PURCHASE with PINCALIBER
# 4   POS PURCHASE with PINGIANT 0774
# 5                      POS PURCHASE
# ...

# %%
oct_df.reset_index(drop=True,inplace=True)
# oct_df.drop(['Index'],axis=1,inplace=True)
print(oct_df)
# Out:
# 2                                  Transaction Number        Date  \
# 0   20201030000000[-5:EST]*-500.00*13**POS PURCHAS...  10/30/2020
# 1   20201030000000[-5:EST]*-5.13*13**POS PURCHASE ...  10/30/2020
# 2      20201029000000[-5:EST]*-31.10*42**POS PURCHASE  10/29/2020
# 3   20201029000000[-5:EST]*-47.56*13**POS PURCHASE...  10/29/2020
# 4   20201028000000[-5:EST]*-9.34*42**POS PURCHASE ...  10/28/2020
# ..                                                ...         ...
# 76  20201005000000[-5:EST]*-6.60*42**POS PURCHASE ...   10/5/2020
# 77  20201005000000[-5:EST]*-14.47*42**POS PURCHASE...   10/5/2020
# 78  20201005000000[-5:EST]*-4.74*13**POS PURCHASE ...   10/5/2020
# 79  20201005000000[-5:EST]*147.33*512**INTERNET TR...   10/5/2020
# 80     20201002000000[-5:EST]*-10.48*42**POS PURCHASE   10/2/2020
#
# 2                       Description  \
# 0      POS PURCHASE with PINCALIBER
# 1   POS PURCHASE with PINGIANT 0774
# 2                      POS PURCHASE
# ...

# %%
oct_df
# Out:
# 2                                  Transaction Number        Date  \
# 0   20201030000000[-5:EST]*-500.00*13**POS PURCHAS...  10/30/2020
# 1   20201030000000[-5:EST]*-5.13*13**POS PURCHASE ...  10/30/2020
# 2      20201029000000[-5:EST]*-31.10*42**POS PURCHASE  10/29/2020
# 3   20201029000000[-5:EST]*-47.56*13**POS PURCHASE...  10/29/2020
# 4   20201028000000[-5:EST]*-9.34*42**POS PURCHASE ...  10/28/2020
# ..                                                ...         ...
# 76  20201005000000[-5:EST]*-6.60*42**POS PURCHASE ...   10/5/2020
# 77  20201005000000[-5:EST]*-14.47*42**POS PURCHASE...   10/5/2020
# 78  20201005000000[-5:EST]*-4.74*13**POS PURCHASE ...   10/5/2020
# 79  20201005000000[-5:EST]*147.33*512**INTERNET TR...   10/5/2020
# 80     20201002000000[-5:EST]*-10.48*42**POS PURCHASE   10/2/2020
#
# 2                       Description  \
# 0      POS PURCHASE with PINCALIBER
# 1   POS PURCHASE with PINGIANT 0774
# 2                      POS PURCHASE
# ...

# %%
oct_df['Category'] = 'Default'

# %%
oct_df
# Out:
# 2                                  Transaction Number        Date  \
# 0   20201030000000[-5:EST]*-500.00*13**POS PURCHAS...  10/30/2020
# 1   20201030000000[-5:EST]*-5.13*13**POS PURCHASE ...  10/30/2020
# 2      20201029000000[-5:EST]*-31.10*42**POS PURCHASE  10/29/2020
# 3   20201029000000[-5:EST]*-47.56*13**POS PURCHASE...  10/29/2020
# 4   20201028000000[-5:EST]*-9.34*42**POS PURCHASE ...  10/28/2020
# ..                                                ...         ...
# 76  20201005000000[-5:EST]*-6.60*42**POS PURCHASE ...   10/5/2020
# 77  20201005000000[-5:EST]*-14.47*42**POS PURCHASE...   10/5/2020
# 78  20201005000000[-5:EST]*-4.74*13**POS PURCHASE ...   10/5/2020
# 79  20201005000000[-5:EST]*147.33*512**INTERNET TR...   10/5/2020
# 80     20201002000000[-5:EST]*-10.48*42**POS PURCHASE   10/2/2020
#
# 2                       Description  \
# 0      POS PURCHASE with PINCALIBER
# 1   POS PURCHASE with PINGIANT 0774
# 2                      POS PURCHASE
# ...

# %%
for x in oct_df['description']:
    #print(x)
    if 'INTERNET TRANSFER' in x:
        print(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-627c20f000cd> in <module>
# ----> 1 for x in oct_df.data:
#       2     #print(x)
#       3     if 'INTERNET TRANSFER' in x:
#       4         print(x)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'data'

# %%
oct_df['Amount Debit'].fillna(0,inplace=True)

# %%
oct_df['Amount Credit'].fillna(0,inplace=True)

# %%
oct_df['Descr'] = oct_df['Transaction Number'] + ' / ' + oct_df['Description']

# %%
oct_df
# Out:
# 2                                  Transaction Number        Date  \
# 0   20201030000000[-5:EST]*-500.00*13**POS PURCHAS...  10/30/2020
# 1   20201030000000[-5:EST]*-5.13*13**POS PURCHASE ...  10/30/2020
# 2      20201029000000[-5:EST]*-31.10*42**POS PURCHASE  10/29/2020
# 3   20201029000000[-5:EST]*-47.56*13**POS PURCHASE...  10/29/2020
# 4   20201028000000[-5:EST]*-9.34*42**POS PURCHASE ...  10/28/2020
# ..                                                ...         ...
# 76  20201005000000[-5:EST]*-6.60*42**POS PURCHASE ...   10/5/2020
# 77  20201005000000[-5:EST]*-14.47*42**POS PURCHASE...   10/5/2020
# 78  20201005000000[-5:EST]*-4.74*13**POS PURCHASE ...   10/5/2020
# 79  20201005000000[-5:EST]*147.33*512**INTERNET TR...   10/5/2020
# 80     20201002000000[-5:EST]*-10.48*42**POS PURCHASE   10/2/2020
#
# 2                       Description  \
# 0      POS PURCHASE with PINCALIBER
# 1   POS PURCHASE with PINGIANT 0774
# 2                      POS PURCHASE
# ...

# %%
oct_df['Transaction Number'].apply(lambda x: x.split('**')[1])
# Out:
# 0        POS PURCHASE with PINCALIBER
# 1     POS PURCHASE with PINGIANT 0774
# 2                        POS PURCHASE
# 3     POS PURCHASE with PINGIANT 0774
# 4       POS PURCHASE Non-PINUBER TRIP
#                    ...
# 76        POS PURCHASE Non-PINCORADOS
# 77        POS PURCHASE Non-PINCORADOS
# 78    POS PURCHASE with PINBEST WORLD
# 79            INTERNET TRANSFER FROM:
# 80                       POS PURCHASE
# Name: Transaction Number, Length: 81, dtype: object

# %%
oct_df['Transaction Number']
# Out:
# 0     20201030000000[-5:EST]*-500.00*13**POS PURCHAS...
# 1     20201030000000[-5:EST]*-5.13*13**POS PURCHASE ...
# 2        20201029000000[-5:EST]*-31.10*42**POS PURCHASE
# 3     20201029000000[-5:EST]*-47.56*13**POS PURCHASE...
# 4     20201028000000[-5:EST]*-9.34*42**POS PURCHASE ...
#                             ...
# 76    20201005000000[-5:EST]*-6.60*42**POS PURCHASE ...
# 77    20201005000000[-5:EST]*-14.47*42**POS PURCHASE...
# 78    20201005000000[-5:EST]*-4.74*13**POS PURCHASE ...
# 79    20201005000000[-5:EST]*147.33*512**INTERNET TR...
# 80       20201002000000[-5:EST]*-10.48*42**POS PURCHASE
# Name: Transaction Number, Length: 81, dtype: object

# %%
oct_df
# Out:
# 2                                  Transaction Number        Date  \
# 0   20201030000000[-5:EST]*-500.00*13**POS PURCHAS...  10/30/2020
# 1   20201030000000[-5:EST]*-5.13*13**POS PURCHASE ...  10/30/2020
# 2      20201029000000[-5:EST]*-31.10*42**POS PURCHASE  10/29/2020
# 3   20201029000000[-5:EST]*-47.56*13**POS PURCHASE...  10/29/2020
# 4   20201028000000[-5:EST]*-9.34*42**POS PURCHASE ...  10/28/2020
# ..                                                ...         ...
# 76  20201005000000[-5:EST]*-6.60*42**POS PURCHASE ...   10/5/2020
# 77  20201005000000[-5:EST]*-14.47*42**POS PURCHASE...   10/5/2020
# 78  20201005000000[-5:EST]*-4.74*13**POS PURCHASE ...   10/5/2020
# 79  20201005000000[-5:EST]*147.33*512**INTERNET TR...   10/5/2020
# 80     20201002000000[-5:EST]*-10.48*42**POS PURCHASE   10/2/2020
#
# 2                       Description  \
# 0      POS PURCHASE with PINCALIBER
# 1   POS PURCHASE with PINGIANT 0774
# 2                      POS PURCHASE
# ...

# %%
oct_df['Transaction Number'] = oct_df['Transaction Number'].apply(lambda x: x.split('**')[1])

# %%
oct_df['Transaction Number']
# Out:
# 0        POS PURCHASE with PINCALIBER
# 1     POS PURCHASE with PINGIANT 0774
# 2                        POS PURCHASE
# 3     POS PURCHASE with PINGIANT 0774
# 4       POS PURCHASE Non-PINUBER TRIP
#                    ...
# 76        POS PURCHASE Non-PINCORADOS
# 77        POS PURCHASE Non-PINCORADOS
# 78    POS PURCHASE with PINBEST WORLD
# 79            INTERNET TRANSFER FROM:
# 80                       POS PURCHASE
# Name: Transaction Number, Length: 81, dtype: object

# %%
oct_df
# Out:
# 2                Transaction Number        Date  \
# 0      POS PURCHASE with PINCALIBER  10/30/2020
# 1   POS PURCHASE with PINGIANT 0774  10/30/2020
# 2                      POS PURCHASE  10/29/2020
# 3   POS PURCHASE with PINGIANT 0774  10/29/2020
# 4     POS PURCHASE Non-PINUBER TRIP  10/28/2020
# ..                              ...         ...
# 76      POS PURCHASE Non-PINCORADOS   10/5/2020
# 77      POS PURCHASE Non-PINCORADOS   10/5/2020
# 78  POS PURCHASE with PINBEST WORLD   10/5/2020
# 79          INTERNET TRANSFER FROM:   10/5/2020
# 80                     POS PURCHASE   10/2/2020
#
# 2                       Description  \
# 0      POS PURCHASE with PINCALIBER
# 1   POS PURCHASE with PINGIANT 0774
# 2                      POS PURCHASE
# 3   POS PURCHASE with PINGIANT 0774
# 4     POS PURCHASE Non-PINUBER TRIP
# ..                              ...
# 76      POS PURCHASE Non-PINCORADOS
# 77      POS PURCHASE Non-PINCORADOS
# 78  POS PURCHASE with PINBEST WORLD
# ...

# %%
oct_df['Memo'].dtypes
# Out:
# dtype('O')

# %%
oct_df['Memo'].apply(lambda x: x)
# Out:
# 0     COLLISION 1706 ARLINGTON VA088816 *****1574 10...
# 1                 ARLINGTON VA 001*****1574 10/29 19:18
# 2     Non-PINAmazon.com*2T40W5IX2 Amzn.com/bill WAIN...
# 3                 ARLINGTON VA 001*****1574 10/28 19:21
# 4          HELP.UBER.COM CA IN0002*****1574 10/28 06:00
#                             ...
# 76    RESTAURANT WASHINGTON DC090207 *****1574 10/02...
# 77    RESTAURANT WASHINGTON DC090207 *****1574 10/02...
# 78            WASHINGTON DC 027750*****1574 10/02 18:39
# 79                                           DDXXXX5941
# 80    Non-PINAMAZON.COM*MK5QF04G2 AM AMZN.COM/BILL W...
# Name: Memo, Length: 81, dtype: object

# %%
type(oct_df['Memo'][0])
# Out:
# str

# %%
type(oct_df['Memo'][11])
# Out:
# str

# %%
oct_df['Memo'].fillna('Default',inplace=True)

# %%
oct_df['Memo'] = oct_df['Memo'].apply(lambda x: x.split('*****')[0])

# %%
oct_df
# Out:
# 2                Transaction Number        Date  \
# 0      POS PURCHASE with PINCALIBER  10/30/2020
# 1   POS PURCHASE with PINGIANT 0774  10/30/2020
# 2                      POS PURCHASE  10/29/2020
# 3   POS PURCHASE with PINGIANT 0774  10/29/2020
# 4     POS PURCHASE Non-PINUBER TRIP  10/28/2020
# ..                              ...         ...
# 76      POS PURCHASE Non-PINCORADOS   10/5/2020
# 77      POS PURCHASE Non-PINCORADOS   10/5/2020
# 78  POS PURCHASE with PINBEST WORLD   10/5/2020
# 79          INTERNET TRANSFER FROM:   10/5/2020
# 80                     POS PURCHASE   10/2/2020
#
# 2                       Description  \
# 0      POS PURCHASE with PINCALIBER
# 1   POS PURCHASE with PINGIANT 0774
# 2                      POS PURCHASE
# 3   POS PURCHASE with PINGIANT 0774
# 4     POS PURCHASE Non-PINUBER TRIP
# ..                              ...
# 76      POS PURCHASE Non-PINCORADOS
# 77      POS PURCHASE Non-PINCORADOS
# 78  POS PURCHASE with PINBEST WORLD
# ...

# %%
oct_df.drop(['Descr','Description'],axis=1,inplace=True)

# %%
oct_df
# Out:
# 2                Transaction Number        Date  \
# 0      POS PURCHASE with PINCALIBER  10/30/2020
# 1   POS PURCHASE with PINGIANT 0774  10/30/2020
# 2                      POS PURCHASE  10/29/2020
# 3   POS PURCHASE with PINGIANT 0774  10/29/2020
# 4     POS PURCHASE Non-PINUBER TRIP  10/28/2020
# ..                              ...         ...
# 76      POS PURCHASE Non-PINCORADOS   10/5/2020
# 77      POS PURCHASE Non-PINCORADOS   10/5/2020
# 78  POS PURCHASE with PINBEST WORLD   10/5/2020
# 79          INTERNET TRANSFER FROM:   10/5/2020
# 80                     POS PURCHASE   10/2/2020
#
# 2                                                Memo Amount Debit  \
# 0                  COLLISION 1706 ARLINGTON VA088816          -500
# 1                                    ARLINGTON VA 001        -5.13
# 2   Non-PINAmazon.com*2T40W5IX2 Amzn.com/bill WAIN...        -31.1
# 3                                    ARLINGTON VA 001       -47.56
# ...

# %%
oct_df['Content'] = oct_df['Transaction Number'] + ' / ' + oct_df['Memo']

# %%
oct_df
# Out:
# 2                Transaction Number        Date  \
# 0      POS PURCHASE with PINCALIBER  10/30/2020
# 1   POS PURCHASE with PINGIANT 0774  10/30/2020
# 2                      POS PURCHASE  10/29/2020
# 3   POS PURCHASE with PINGIANT 0774  10/29/2020
# 4     POS PURCHASE Non-PINUBER TRIP  10/28/2020
# ..                              ...         ...
# 76      POS PURCHASE Non-PINCORADOS   10/5/2020
# 77      POS PURCHASE Non-PINCORADOS   10/5/2020
# 78  POS PURCHASE with PINBEST WORLD   10/5/2020
# 79          INTERNET TRANSFER FROM:   10/5/2020
# 80                     POS PURCHASE   10/2/2020
#
# 2                                                Memo Amount Debit  \
# 0                  COLLISION 1706 ARLINGTON VA088816          -500
# 1                                    ARLINGTON VA 001        -5.13
# 2   Non-PINAmazon.com*2T40W5IX2 Amzn.com/bill WAIN...        -31.1
# 3                                    ARLINGTON VA 001       -47.56
# ...

# %%
oct_df.drop(['Transaction Number','Date','Memo'],axis=1,inplace=True)

# %%
oct_df
# Out:
# 2  Amount Debit Amount Credit Category  \
# 0          -500             0  Default
# 1         -5.13             0  Default
# 2         -31.1             0  Default
# 3        -47.56             0  Default
# 4         -9.34             0  Default
# ..          ...           ...      ...
# 76         -6.6             0  Default
# 77       -14.47             0  Default
# 78        -4.74             0  Default
# 79            0        147.33  Default
# 80       -10.48             0  Default
#
# 2                                             Content
# 0   POS PURCHASE with PINCALIBER / COLLISION 1706 ...
# 1   POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...
# 2   POS PURCHASE / Non-PINAmazon.com*2T40W5IX2 Amz...
# 3   POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...
# 4   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...
# ..                                                ...
# 76  POS PURCHASE Non-PINCORADOS / RESTAURANT WASHI...
# ...

# %%
oct_df['Amount'] = oct_df['Amount Debit'] + oct_df['Amount Credit']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     148     try:
# --> 149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     120     if result is None:
# --> 121         result = _evaluate_standard(op, op_str, a, b)
#     122
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
# ...

# %%
type(oct_df['Amount Debit'][0])
# Out:
# str

# %%
oct_df['Amount'] = oct_df['Amount Debit'].astype(float) + oct_df['Amount Credit'].astype(float)

# %%
oct_df.drop(['Amount Debit','Amount Credit'],axis=1,inplace=True)

# %%
oct_df
# Out:
# 2  Category                                            Content  Amount
# 0   Default  POS PURCHASE with PINCALIBER / COLLISION 1706 ... -500.00
# 1   Default  POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...   -5.13
# 2   Default  POS PURCHASE / Non-PINAmazon.com*2T40W5IX2 Amz...  -31.10
# 3   Default  POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...  -47.56
# 4   Default  POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -9.34
# ..      ...                                                ...     ...
# 76  Default  POS PURCHASE Non-PINCORADOS / RESTAURANT WASHI...   -6.60
# 77  Default  POS PURCHASE Non-PINCORADOS / RESTAURANT WASHI...  -14.47
# 78  Default  POS PURCHASE with PINBEST WORLD / WASHINGTON D...   -4.74
# 79  Default               INTERNET TRANSFER FROM: / DDXXXX5941  147.33
# 80  Default  POS PURCHASE / Non-PINAMAZON.COM*MK5QF04G2 AM ...  -10.48
#
# [81 rows x 3 columns]

# %%
pd.set_option('display.max_rows',None)

# %%
oct_df
# Out:
# 2  Category                                            Content   Amount
# 0   Default  POS PURCHASE with PINCALIBER / COLLISION 1706 ...  -500.00
# 1   Default  POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...    -5.13
# 2   Default  POS PURCHASE / Non-PINAmazon.com*2T40W5IX2 Amz...   -31.10
# 3   Default  POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...   -47.56
# 4   Default  POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...    -9.34
# 5   Default  POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...    -9.78
# 6   Default  POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...    -3.00
# 7   Default         INTERNET TRANSFER TO: DDXXXX5941 / Default   -94.83
# 8   Default                WASHINGTON GAS/PAYMENTEvan / Barnes   -81.96
# 9   Default            USAA PC/PAYMENTWALTER COLEMAN / Default  -187.68
# 10  Default  POS PURCHASE / Non-PINRAPPAHANNOCK COFFEE & R ...    -2.40
# 11  Default  POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...   -52.51
# ...

# %%
df = oct_df

# %%
#Wrangle data first, then drop all the columns so it's a little easier
