# %%
import pandas as pd
import os
os.chdir('..')

import auto_budget
from auto_budget.content_encoder import content_encoder
from auto_budget.model_prep import model_prep_select
from auto_budget.auto_model import budget_categorizer

# create mechanical object
new = '../data/RawStatements/ExportedTransactions-9.csv'
old = '../data/CleanedStatements/full_cat_enc_fresh.xlsx'

bc = budget_categorizer(new,old)
bc.predict_with_model()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/colemanwalterj/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/colemanwalterj/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/colemanwalterj/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# /opt/homebrew/Caskroom/miniforge/base/envs/tf_m1/lib/python3.8/site-packages/sklearn/utils/validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# ...

# %%
# create un-encoded full dataset, but leave encoded categories for simplicity
# import pandas as pd
# quick_edit = pd.read_excel('../data/CleanedStatements/fully_catized_encoded.xlsx')
# quick_edit.drop(['VD_year',     'PT_total_seconds',
#        'sin_PT_total_seconds', 'cos_PT_total_seconds',              'PD_year',
#                'sin_PD_month',         'cos_PD_month',           'sin_PD_day',
#                  'cos_PD_day',         'sin_VD_month',         'cos_VD_month',
#                  'sin_VD_day',           'cos_VD_day',   'Payment_Method_Cat',
#                             0,                      1,                      2,
#                             3],axis=1,inplace=True)
# quick_edit.to_excel('../data/CleanedStatements/full_cat_enc_fresh.xlsx',index=False)
os.getcwd()
