# %%
#Must import, rename columns, delete header rows, reset index, consolidate string and (fillna first) ints, 
#then drop the useless columns, but add category column
import pandas as pd

# %%
import pandas as pd
oct_df = pd.read_csv('OctoberChecking.csv')
oct_df.columns = oct_df.loc[2]
oct_df.drop([0,1,2],inplace=True)
oct_df['Amount Debit'].fillna(0,inplace=True)
oct_df['Amount Credit'].fillna(0,inplace=True)
oct_df['Memo'].fillna('Default',inplace=True)
oct_df['Transaction Number'] = oct_df['Transaction Number'].apply(lambda x: x.split('**')[1])
oct_df['Memo'] = oct_df['Memo'].apply(lambda x: x.split('*****')[0])
oct_df['Content'] = oct_df['Transaction Number'] + ' / ' + oct_df['Memo']
oct_df['Amount'] = oct_df['Amount Debit'].astype(float) + oct_df['Amount Credit'].astype(float)
oct_df['Category'] = 'Default'
oct_df.drop(oct_df[oct_df['Content'].str.contains("INTERNET TRANSFER",na=False)].index,inplace=True)
oct_df.reset_index(inplace=True)
oct_df.drop(['index','Transaction Number','Date','Description','Memo','Amount Debit','Amount Credit',
             'Balance','Check Number','Fees  '],axis=1,inplace=True)
pd.set_option('display.max_rows',None)
pd.set_option('display.max_rows',None)
pd.set_option('display.width', 1000)

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_rows',None)
pd.set_option('display.width', 1000)

# %%
oct_df.reset_index(inplace=True)

# %%
oct_df.drop('index',axis=1,inplace=True)

# %%
oct_df.drop(['index','Transaction Number','Date','Description','Memo','Amount Debit','Amount Credit','Balance',
             'Check Number','Fees  '],axis=1,inplace=True)

# %%
oct_df
# Out:
# 2                                             Content  Amount Category
# 0   POS PURCHASE with PINCALIBER / COLLISION 1706 ... -500.00  Default
# 1   POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...   -5.13  Default
# 2   POS PURCHASE / Non-PINAmazon.com*2T40W5IX2 Amz...  -31.10  Default
# 3   POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...  -47.56  Default
# 4   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -9.34  Default
# ..                                                ...     ...      ...
# 69  POS PURCHASE Non-PINSTARBUCKS*1 / STORE 24498 ...   -2.28  Default
# 70  POS PURCHASE Non-PINCORADOS / RESTAURANT WASHI...   -6.60  Default
# 71  POS PURCHASE Non-PINCORADOS / RESTAURANT WASHI...  -14.47  Default
# 72  POS PURCHASE with PINBEST WORLD / WASHINGTON D...   -4.74  Default
# 73  POS PURCHASE / Non-PINAMAZON.COM*MK5QF04G2 AM ...  -10.48  Default
#
# [74 rows x 3 columns]

# %%
oct_df.describe()
# Out:
# 2           Amount
# count    81.000000
# mean     -6.860494
# std     426.052175
# min   -2129.000000
# 25%     -41.990000
# 50%     -17.010000
# 75%      -3.500000
# max    2104.370000

# %%
oct_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81 entries, 3 to 83
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Content   81 non-null     object
#  1   Amount    81 non-null     float64
#  2   Category  81 non-null     object
# dtypes: float64(1), object(2)
# memory usage: 2.5+ KB

# %%
oct_df.drop(oct_df[oct_df['Content'].str.contains("INTERNET TRANSFER",na=False)].index)
# Out:
# 2                                             Content  Amount Category
# 0   POS PURCHASE with PINCALIBER / COLLISION 1706 ... -500.00  Default
# 1   POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...   -5.13  Default
# 2   POS PURCHASE / Non-PINAmazon.com*2T40W5IX2 Amz...  -31.10  Default
# 3   POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...  -47.56  Default
# 4   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -9.34  Default
# ..                                                ...     ...      ...
# 75  POS PURCHASE Non-PINSTARBUCKS*1 / STORE 24498 ...   -2.28  Default
# 76  POS PURCHASE Non-PINCORADOS / RESTAURANT WASHI...   -6.60  Default
# 77  POS PURCHASE Non-PINCORADOS / RESTAURANT WASHI...  -14.47  Default
# 78  POS PURCHASE with PINBEST WORLD / WASHINGTON D...   -4.74  Default
# 80  POS PURCHASE / Non-PINAMAZON.COM*MK5QF04G2 AM ...  -10.48  Default
#
# [74 rows x 3 columns]

# %%
oct_df.drop(oct_df[oct_df['Content'].str.contains("INTERNET TRANSFER",na=False)].index,inplace=True)

# %%
oct_df.reset_index(inplace=True)
oct_df.drop('index',axis=1,inplace=True)

# %%
oct_df
# Out:
# 2                                             Content  Amount Category
# 0                                                 NaN     NaN      NaN
# 1                                                 NaN     NaN      NaN
# 2                                                 NaN     NaN      NaN
# 3                                                 NaN     NaN      NaN
# 4   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -9.34  Default
# ..                                                ...     ...      ...
# 69                                                NaN     NaN      NaN
# 70                                                NaN     NaN      NaN
# 71                                                NaN     NaN      NaN
# 72                                                NaN     NaN      NaN
# 73                                                NaN     NaN      NaN
#
# [74 rows x 3 columns]

# %%
df = oct_df.copy()

# %%
df
# Out:
# 2                                             Content  Amount Category
# 0   POS PURCHASE with PINCALIBER / COLLISION 1706 ... -500.00  Default
# 1   POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...   -5.13  Default
# 2   POS PURCHASE / Non-PINAmazon.com*2T40W5IX2 Amz...  -31.10  Default
# 3   POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...  -47.56  Default
# 4   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -9.34  Default
# ..                                                ...     ...      ...
# 69  POS PURCHASE Non-PINSTARBUCKS*1 / STORE 24498 ...   -2.28  Default
# 70  POS PURCHASE Non-PINCORADOS / RESTAURANT WASHI...   -6.60  Default
# 71  POS PURCHASE Non-PINCORADOS / RESTAURANT WASHI...  -14.47  Default
# 72  POS PURCHASE with PINBEST WORLD / WASHINGTON D...   -4.74  Default
# 73  POS PURCHASE / Non-PINAMAZON.COM*MK5QF04G2 AM ...  -10.48  Default
#
# [74 rows x 3 columns]

# %%
filter = df['Content'].str.contains("UBER EATS",na=False)

# %%
df.where(filter)
# Out:
# 2                                             Content  Amount Category
# 0                                                 NaN     NaN      NaN
# 1                                                 NaN     NaN      NaN
# 2                                                 NaN     NaN      NaN
# 3                                                 NaN     NaN      NaN
# 4                                                 NaN     NaN      NaN
# 5                                                 NaN     NaN      NaN
# 6                                                 NaN     NaN      NaN
# 7                                                 NaN     NaN      NaN
# 8                                                 NaN     NaN      NaN
# 9                                                 NaN     NaN      NaN
# 10                                                NaN     NaN      NaN
# 11                                                NaN     NaN      NaN
# ...

# %%
df.where(filter)['Amount'].fillna(0).sum()
# Out:
# -126.57000000000001

# %%
df
# Out:
# 2                                             Content   Amount Category
# 0   POS PURCHASE with PINCALIBER / COLLISION 1706 ...  -500.00  Default
# 1   POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...    -5.13  Default
# 2   POS PURCHASE / Non-PINAmazon.com*2T40W5IX2 Amz...   -31.10  Default
# 3   POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...   -47.56  Default
# 4   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...    -9.34  Default
# 5   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...    -9.78  Default
# 6   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...    -3.00  Default
# 7                 WASHINGTON GAS/PAYMENTEvan / Barnes   -81.96  Default
# 8             USAA PC/PAYMENTWALTER COLEMAN / Default  -187.68  Default
# 9   POS PURCHASE / Non-PINRAPPAHANNOCK COFFEE & R ...    -2.40  Default
# 10  POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...   -52.51  Default
# 11            DOMINION ENERGY/BILLPAYWALTER / COLEMAN   -59.55  Default
# ...

# %%
pos_filter = df['Content'].str.contains("POS PURCHASE",na=False)

# %%
df.where(pos_filter).dropna()
# Out:
# 2                                             Content  Amount Category
# 0   POS PURCHASE with PINCALIBER / COLLISION 1706 ... -500.00  Default
# 1   POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...   -5.13  Default
# 2   POS PURCHASE / Non-PINAmazon.com*2T40W5IX2 Amz...  -31.10  Default
# 3   POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...  -47.56  Default
# 4   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -9.34  Default
# 5   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -9.78  Default
# 6   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -3.00  Default
# 9   POS PURCHASE / Non-PINRAPPAHANNOCK COFFEE & R ...   -2.40  Default
# 10  POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...  -52.51  Default
# 12  POS PURCHASE Non-PINMCDONALD'S / F20860 WASHIN...   -8.34  Default
# 13  POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM ...   -3.50  Default
# 14  POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...  -11.80  Default
# ...

# %%
df.where(pos_filter).dropna()['Amount'].sum()
# Out:
# -2206.8699999999994

# %%
df['Content'].value_counts()
# Out:
# POS PURCHASE with PINGIANT 0774 / ARLINGTON VA 001                       6
# POS PURCHASE with PINHARRIS / TEETER #3 ARLINGTON VA 380371              4
# VENMO/PAYMENTWALTER COLEMAN / Default                                    3
# POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM CA INC700                  2
# POS PURCHASE Non-PINCORADOS / RESTAURANT WASHINGTON DC090207             2
# DOMINION ENERGY/BILLPAYWALTER / COLEMAN                                  2
# Accenture Federa/PAYRLL / DEPColeman, Walter J                           2
# VENMO/CASHOUTWALTER COLEMAN / Default                                    2
# POS PURCHASE Non-PINNAZRET / RESTAURANT 703-3479911 VA768720             2
# POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM CA IN0002                  1
# POS PURCHASE Non-PINVHC MYCHART / E-COMMERCE 703-5585000 VA788153        1
# ARLINGTON COUNTY/ARLCO PMTWALTER / Default                               1
# ...

# %%
df.sort_values(by=['Amount'])
# Out:
# 2                                             Content   Amount Category
# 22              VENMO/PAYMENTWALTER COLEMAN / Default  -668.75  Default
# 0   POS PURCHASE with PINCALIBER / COLLISION 1706 ...  -500.00  Default
# 53  POS PURCHASE Non-PINVHC MYCHART / E-COMMERCE 7...  -216.87  Default
# 17  POS PURCHASE Non-PINPAYPAL *ETS / GRE 402-935-...  -205.00  Default
# 8             USAA PC/PAYMENTWALTER COLEMAN / Default  -187.68  Default
# 35  POS PURCHASE Non-PINDISTRICT / MARTIAL ARTS 85...  -159.00  Default
# 52         ARLINGTON COUNTY/ARLCO PMTWALTER / Default  -151.80  Default
# 60  POS PURCHASE Non-PINHOLIDAY INN / EXPRESS BRA ...  -112.86  Default
# 56            DOMINION ENERGY/BILLPAYWALTER / COLEMAN  -111.79  Default
# 7                 WASHINGTON GAS/PAYMENTEvan / Barnes   -81.96  Default
# 55         VERIZON/PAYMENTRECWALTER COLEMAN / Default   -79.99  Default
# 33  POS PURCHASE with PINHARRIS / TEETER #3 ARLING...   -64.52  Default
# ...

# %%
df[df['Amount'] > 0]['Amount'].sum() - (2* 2104.37)
# Out:
# 301.78000000000065

# %%
df

# %%
df[(df['Amount'] < 0) & (df['Amount'] > -79)]
# Out:
# 2                                             Content  Amount Category
# 1   POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...   -5.13  Default
# 2   POS PURCHASE / Non-PINAmazon.com*2T40W5IX2 Amz...  -31.10  Default
# 3   POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...  -47.56  Default
# 4   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -9.34  Default
# 5   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -9.78  Default
# 6   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -3.00  Default
# 9   POS PURCHASE / Non-PINRAPPAHANNOCK COFFEE & R ...   -2.40  Default
# 10  POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...  -52.51  Default
# 11            DOMINION ENERGY/BILLPAYWALTER / COLEMAN  -59.55  Default
# 12  POS PURCHASE Non-PINMCDONALD'S / F20860 WASHIN...   -8.34  Default
# 13  POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM ...   -3.50  Default
# 14  POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...  -11.80  Default
# ...

# %%
df[(df['Amount'] < 0) & (df['Amount'] > -79)].describe()
# Out:
# 2         Amount
# count  57.000000
# mean  -19.222632
# std    16.835234
# min   -64.520000
# 25%   -24.420000
# 50%   -14.470000
# 75%    -6.600000
# max    -1.050000

# %%
the_df = df[(df['Amount'] < 0) & (df['Amount'] > -79)]

# %%
sml_df = df[(df['Amount'] < 0) & (df['Amount'] > -14.47)]

# %%
med_df = df[(df['Amount'] < -14.47) & (df['Amount'] > -79)]

# %%
sml_df
# Out:
# 2                                             Content  Amount Category
# 1   POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...   -5.13  Default
# 4   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -9.34  Default
# 5   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -9.78  Default
# 6   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -3.00  Default
# 9   POS PURCHASE / Non-PINRAPPAHANNOCK COFFEE & R ...   -2.40  Default
# 12  POS PURCHASE Non-PINMCDONALD'S / F20860 WASHIN...   -8.34  Default
# 13  POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM ...   -3.50  Default
# 14  POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...  -11.80  Default
# 16  POS PURCHASE Non-PINMUSEUM OF / THE BIBLE WASH...  -10.59  Default
# 18  POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -9.70  Default
# 20  POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...  -11.35  Default
# 23  POS PURCHASE Non-PINTortas y / Tacos La Chiqu ...  -12.55  Default
# ...

# %%
med_df
# Out:
# 2                                             Content  Amount Category
# 2   POS PURCHASE / Non-PINAmazon.com*2T40W5IX2 Amz...  -31.10  Default
# 3   POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...  -47.56  Default
# 10  POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...  -52.51  Default
# 11            DOMINION ENERGY/BILLPAYWALTER / COLEMAN  -59.55  Default
# 15  POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM ...  -17.51  Default
# 19  POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM ...  -21.32  Default
# 21  POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...  -48.58  Default
# 24  POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM ...  -18.51  Default
# 27  POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM ...  -23.08  Default
# 29  POS PURCHASE Non-PINTAJ OF / INDIA ARLINGTON V...  -20.60  Default
# 32  POS PURCHASE Non-PINNAZRET / RESTAURANT 703-34...  -19.79  Default
# 33  POS PURCHASE with PINHARRIS / TEETER #3 ARLING...  -64.52  Default
# ...

# %%
the_df
# Out:
# 2                                             Content  Amount Category
# 1   POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...   -5.13  Default
# 2   POS PURCHASE / Non-PINAmazon.com*2T40W5IX2 Amz...  -31.10  Default
# 3   POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...  -47.56  Default
# 4   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -9.34  Default
# 5   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -9.78  Default
# 6   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -3.00  Default
# 9   POS PURCHASE / Non-PINRAPPAHANNOCK COFFEE & R ...   -2.40  Default
# 10  POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...  -52.51  Default
# 11            DOMINION ENERGY/BILLPAYWALTER / COLEMAN  -59.55  Default
# 12  POS PURCHASE Non-PINMCDONALD'S / F20860 WASHIN...   -8.34  Default
# 13  POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM ...   -3.50  Default
# 14  POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...  -11.80  Default
# ...

# %%
med_df
# Out:
# 2                                             Content  Amount Category
# 2   POS PURCHASE / Non-PINAmazon.com*2T40W5IX2 Amz...  -31.10  Default
# 3   POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...  -47.56  Default
# 10  POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...  -52.51  Default
# 11            DOMINION ENERGY/BILLPAYWALTER / COLEMAN  -59.55  Default
# 15  POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM ...  -17.51  Default
# 19  POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM ...  -21.32  Default
# 21  POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...  -48.58  Default
# 24  POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM ...  -18.51  Default
# 27  POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM ...  -23.08  Default
# 29  POS PURCHASE Non-PINTAJ OF / INDIA ARLINGTON V...  -20.60  Default
# 32  POS PURCHASE Non-PINNAZRET / RESTAURANT 703-34...  -19.79  Default
# 33  POS PURCHASE with PINHARRIS / TEETER #3 ARLING...  -64.52  Default
# ...

# %%
df[df['Content'].str.contains]
