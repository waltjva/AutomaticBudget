# %%
import pandas as pd
df = pd.read_excel('../../data/CleanedStatements/fully_catized_encoded.xlsx')
import nltk
import re
import spacy
import requests
from bs4 import BeautifulSoup
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

from nltk.tokenize.toktok import ToktokTokenizer
import re
from bs4 import BeautifulSoup
# from contractions import CONTRACTION_MAP
import unicodedata

from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

nltk.download('wordnet')

tokenizer = ToktokTokenizer()
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')

def remove_stopwords(text):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    filtered_tokens = [token for token in tokens if token not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)
    return filtered_text

# %%
# nlp = spacy.load('en_core_web_lg')

# %%
# Find below my suggestions:

# 1. Consider the frequency of words, remove any words that occur less than 5 or 10 times,
# this helps us get rid of unique words that are not used frequently, this way our model 
# will not focus on those words.

# 2. W.r.t the above point, try removing the words that are too frequent like the one that 
# occurs more then 100-120 times, this gets rid of the higher frequency words. These 
# threshold values are configurable and solely depends on the use case, there is no right or 
# wrong way to do it.

# 3. Try removing Stop words.

# 4. Try Lemmatisation, it is recommended you experiment with the Lemmatisation after stop 
# words removal and then try the frequency removal method.

# Try these methods and let me know if it worked for you, if not feel free to reach out in 
# the response section, I’ll try to respond sooner.

# %%
df[(-2.5<df['Amount']) & (df['Amount']<-1)]['Amount'].plot.hist(bins=54,alpha=0.5)
import matplotlib.pyplot as plt

# # Creating histogram
# fig, ax = plt.subplots(figsize =(10, 7))
# ax.hist(df[(-40<df['Amount']) & (df['Amount']<-3)]['Amount'], bins = [0, 25, 50, 75, 100])
  
# # Show plot
# plt.show()

# %%
df[(-40<df['Amount']) & (df['Amount']<-3)]['Amount'].plot.box()
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
fig = plt.subplots(figsize=(12,6))
sns.barplot(df['Category'],df[abs(df['Amount']) < 400]['Amount'])
plt.xticks(rotation = 90) 
plt.title('Spending per category')
plt.show()
# Out:
# /Users/colemanwalterj/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
spends = df[df['Amount'] < 0]['Amount'].apply(lambda x: -1*x)
cats = df[df['Amount'] < 0]['Category'].copy()

# %%
len(spends)
# Out:
# 680

# %%
fig = plt.subplots(figsize=(12,6))
plt.pie(spends)
plt.xticks(rotation = 90) 
plt.title('Spending per category')
plt.show()

# %%
import pandas as pd
df = pd.read_excel('../../data/CleanedStatements/fully_catized_encoded.xlsx')
import nltk
import re
import spacy
import requests
from bs4 import BeautifulSoup
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os
from nltk.tokenize.toktok import ToktokTokenizer
# from contractions import CONTRACTION_MAP
import unicodedata

from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import OneHotEncoder
from tensorflow.keras.preprocessing.sequence import pad_sequences

def remove_stopwords(text):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    filtered_tokens = [token for token in tokens if token not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text

def data_corpus_create(content):
    data_corpus=set()
    for row in content:
        for word in row.split(" "):
            if word not in data_corpus:
                data_corpus.add(word)
    return sorted(data_corpus)

lemmatizer = WordNetLemmatizer()

nltk.download('wordnet')
nltk.download('omw-1.4')
tokenizer = ToktokTokenizer()
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')

content = df['Content'].copy()

# build corpus, get count of each word
nltk.FreqDist(content[0].split(' '))

content1 = content.apply(lambda x: re.sub(r"[^a-zA-Z0-9]+", " ", x) )
content2 = content1.apply(lambda x: x.lower())
content3 = content2.apply(lambda x: x.strip())
# create corpus with frequency counts to see what can stay and what can depart
content4 = pd.Series(sorted(content3))
# Create a corpus for all the words
content5 = content4.apply(remove_stopwords)

content6 = content5.apply(lambda x: lemmatizer.lemmatize(x))
content7 = content6.apply(lambda x: re.sub("\d+","",x))
cont = content7.apply(lambda x: re.sub("  "," ",x))
cont = cont.apply(lambda x: x.strip())
cont = cont.apply(lambda x: re.sub("  "," ",x))

data_corpus = data_corpus_create(cont)

# Create dictionary for each unique word, += 1 for each new encounter
d = {}
for row in cont:
    for word in row.split(" "):
        if word not in d.keys():
            d[word] = 1
        else:
            d[word] +=1

word_freq_counts = {k: v for k, v in sorted(d.items(), key=lambda item: item[1], reverse=True)}

ref = list(d.values())

def remove_dict_dat(sentence):
    s = sentence.split(" ")
    for word in s:
        if d[word] < 5:
            s.remove(word)
        elif d[word] > 19:
            s.remove(word)
    return " ".join(s)

cont2 = cont.apply(remove_dict_dat)

data_corpus=data_corpus_create(cont2)

print(len(data_corpus))

cont2 = cont2.apply(lambda x: x.strip())
cont2 = cont2.apply(lambda x: lemmatizer.lemmatize(x))

# converting text to integers
token_docs = [doc.split(" ") for doc in cont2]
all_tokens = set([word for sentence in token_docs for word in sentence])
word_to_idx = {token:idx+1 for idx, token in enumerate(all_tokens)}

# converting the docs to their token ids
X = np.array([[word_to_idx[token] for token in token_doc] for token_doc in token_docs], dtype=object)

# padding the sequences
X_padded = pad_sequences(X, padding="post")

# converting to pandas df
X_df = pd.DataFrame(X_padded)

X_df
# Out:
# ['', 'abi', 'abm', 'accenture', 'acct', 'ach', 'achwalter', 'adams', 'address', 'advanced', 'aetna', 'afghan', 'ah', 'aid', 'air', 'airbnb', 'airport', 'alam', 'aldi', 'alexandria', 'alrington', 'amamzn', 'amazon', 'amelia', 'amzn', 'andrew', 'annandale', 'annapolis', 'anne', 'antonio', 'ap', 'app', 'apple', 'aramark', 'arby', 'arbys', 'arin', 'aris', 'arlco', 'arlington', 'aroma', 'arts', 'ase', 'ashburn', 'atla', 'atlaatlanta', 'atlanta', 'atm', 'atx', 'audible', 'auntie', 'austin', 'auto', 'autozone', 'av', 'ave', 'avznn', 'aws', 'azteca', 'ba', 'backbone', 'bagels', 'bailey', 'baileys', 'bakery', 'balance', 'ballston', 'bank', 'bar', 'barbe', 'barbecharlottesvilvaus', 'barbecue', 'barnes', 'barracks', 'bbb', 'bealeton', 'bear', 'beatriz', 'bell', 'ben', 'benefit', 'benny', 'bento', 'best', 'bethesda', 'bible', 'bier', 'bill', 'billpaywalter', 'billwaus', 'biltmore', 'biscuits', 'bistro', 'bjj', 'blacks', 'bluemont', 'bob', 'bodo', 'bojangles', 'boruramen', 'bowlero', 'boyce', 'boylan', 'boys', 'bra', 'brazili', 'brazilixx', 'bread', 'brewing', 'bris', 'broadneck', 'bronson', 'brooklyn', 'c', 'ca', 'cacnp', 'cafe', 'cain', 'caina', 'cainb', 'cainc', 'cainp', 'caliber', 'camino', 'campero', 'campus', 'canal', 'care', 'cashoutwalter', 'casino', 'casualty', 'catercharlottesvilvaus', 'caus', 'cava', 'cc', 'ce', 'celebrations', 'center', 'centerxx', 'cgusf', 'chalait', 'change', 'charlcharlottesvilvaus', 'charlotesvill', 'charlottes', 'charlottesv', 'charlottesvi', 'charlottesvil', 'charlottesville', 'charlottesvilva', 'charlottesvilvaus', 'charlottesvle', 'charlottesvlevaus', 'chase', 'check', 'chick', 'chicken', 'chickering', 'chiles', 'chiqu', 'christian', 'christians', 'church', 'cider', 'cir', 'circa', 'citgo', 'city', 'cke', 'ckfr', 'ckx', 'cl', 'clarendon', 'claxto', 'closed', 'club', 'co', 'cocharlottesvilvaus', 'coffee', 'cole', 'colem', 'colema', 'coleman', 'collision', 'colonial', 'columbia', 'com', 'comaus', 'comcast', 'comcaus', 'comet', 'commerce', 'comp', 'company', 'concessionscharlottesvilvaus', 'connor', 'cook', 'cookies', 'corados', 'corcharlottesvilvaus', 'corner', 'corp', 'corpxx', 'costco', 'couns', 'county', 'coupes', 'court', 'covemius', 'covenant', 'cow', 'craft', 'cream', 'cross', 'crossr', 'crowne', 'crozet', 'csc', 'cstor', 'ctin', 'ctr', 'cuscatleco', 'cuts', 'cvile', 'cvill', 'cvillcharlottesvilvaus', 'cvs', 'dace', 'dairy', 'data', 'day', 'days', 'dc', 'dcin', 'dcpillar', 'de', 'debit', 'default', 'dein', 'del', 'deluca', 'delucas', 'department', 'depcolem', 'depcoleman', 'deposit', 'depot', 'dept', 'devils', 'dick', 'dicks', 'diner', 'dining', 'direct', 'district', 'dom', 'domain', 'dominion', 'domino', 'donut', 'downtown', 'dr', 'dumfries', 'dumplings', 'dunkin', 'e', 'eat', 'eatery', 'eats', 'ebag', 'ecm', 'edith', 'edx', 'eftwalter', 'egun', 'einsteins', 'el', 'eleven', 'elliewood', 'em', 'emcharlottesvilvaus', 'emmaus', 'emmet', 'energy', 'energyva', 'enterprises', 'eqhs', 'er', 'est', 'ethiopia', 'ets', 'event', 'express', 'ext', 'exxon', 'exxonmobil', 'eyecare', 'eyes', 'f', 'fairfax', 'falls', 'falmouth', 'family', 'famous', 'fanaticos', 'fancy', 'farm', 'farmville', 'fcu', 'federa', 'federal', 'fedloanservicing', 'fee', 'feeita', 'feelin', 'fees', 'fig', 'fil', 'financial', 'fitzroy', 'fontaine', 'food', 'foods', 'fredericksbur', 'free', 'front', 'fry', 'fsb', 'fundrise', 'fundswalter', 'ga', 'gain', 'gainb', 'gainc', 'gainesville', 'gainp', 'gardens', 'gas', 'gaus', 'gb', 'get', 'gia', 'giant', 'godmother', 'gofndme', 'good', 'goods', 'goodscharlottesvilvaus', 'google', 'gosq', 'got', 'graduate', 'grand', 'gre', 'great', 'gretchen', 'grill', 'grit', 'grocery', 'grounds', 'growth', 'grubhub', 'guajiro', 'gym', 'hadensville', 'hagerstown', 'hai', 'hair', 'hall', 'harris', 'hauljt', 'health', 'heights', 'help', 'hicharlottesvilvaus', 'hmrt', 'hmxbdz', 'holey', 'holiday', 'holy', 'home', 'horse', 'hospital', 'hotel', 'house', 'houston', 'hr', 'hsxt', 'htaq', 'httpsleetcode', 'httpswww', 'iad' ...
# 876
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/colemanwalterj/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/colemanwalterj/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# change numeric columns to str for the transaction text
lis = []

for x in X_df.columns:
    lis.append('word'+str(x))
X_df.columns = lis

# %%
# combine original dataframe to the parameterized content dataframe
dff = pd.concat([df,X_df],axis=1)

# %%
# train dc model to see if this column idea works
dff.columns
# Out:
# Index([       'Purchase Date',        'Purchase Time',       'Payment_Method',
#                      'Amount',    'Verification Date',              'Content',
#                    'Category',              'VD_year',     'PT_total_seconds',
#        'sin_PT_total_seconds', 'cos_PT_total_seconds',              'PD_year',
#                'sin_PD_month',         'cos_PD_month',           'sin_PD_day',
#                  'cos_PD_day',         'sin_VD_month',         'cos_VD_month',
#                  'sin_VD_day',           'cos_VD_day',   'Payment_Method_Cat',
#                             0,                      1,                      2,
#                             3,         'Category_Cat',                'word0',
#                       'word1',                'word2',                'word3',
#                       'word4',                'word5',                'word6',
#                       'word7'],
#       dtype='object')

# %%
# os.chdir('..')
from auto_budget import bank_functions_NWFCU as nw
ref = nw.ref_dictionaries(dff)
# Out:
# ({'Dining Out': 0.0,
#   'Entertainment': 1.0,
#   'Extra': 2.0,
#   'Gas': 3.0,
#   'Groceries': 4.0,
#   'Gym': 5.0,
#   'Medical': 6.0,
#   'Misc': 7.0,
#   'Pay Check': 8.0,
#   'Phone': 9.0,
#   'Rent': 10.0,
#   'Student Loans': 11.0,
#   'Tithe': 12.0,
#   'Tolls/Uber/Metro/Parking': 13.0,
#   'USAA Insurance': 14.0,
#   'Utilities': 15.0,
#   'Venmo Extra': 16.0},
#  {0.0: 'Dining Out',
#   1.0: 'Entertainment',
#   2.0: 'Extra',
#   3.0: 'Gas',
#   4.0: 'Groceries',
#   5.0: 'Gym',
#   6.0: 'Medical',
#   7.0: 'Misc',
#   8.0: 'Pay Check',
#   9.0: 'Phone',
#   10.0: 'Rent',
#   11.0: 'Student Loans',
#   12.0: 'Tithe',
#   13.0: 'Tolls/Uber/Metro/Parking',
#   14.0: 'USAA Insurance',
#   15.0: 'Utilities',
#   16.0: 'Venmo Extra'})

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

X = dff.drop(['Purchase Date','Purchase Time','Payment_Method','Verification Date', 'Content', 'Category','PT_total_seconds','Payment_Method_Cat', 'Category_Cat', 'Content'], axis=1)
y = dff['Category_Cat'].copy()

# %%
# test_train_split
# random forest to see if works
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# dectree = DecisionTreeClassifier()

# %%
# figure out how to use index-based words in sklearn 
# https://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html#tokenizing-text-with-scikit-learn

# %%
# dectree.fit(X_train, y_train)
