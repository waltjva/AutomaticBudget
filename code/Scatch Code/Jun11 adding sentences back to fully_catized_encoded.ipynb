# %%
import pandas as pd
import numpy as np

# %%
import datetime as dt

# %%
import bank_functions as bf

# %%
encoded_df = pd.read_excel('fully_catized_fully_encoded.xlsx')

# %%
full_df = pd.read_excel('bank_statements_categorized.xlsx')

# %%
# full_df.drop('Unnamed: 0',axis=1,inplace=True)
full_df['Last_Word'] = full_df['Last_Word'].fillna(value = 'Default')

# %%
encoded_df['Purchase Time'] = encoded_df['Purchase Time'].apply(lambda x: dt.datetime.strptime(x, '%H:%M:%S').time())

# %%
len(encoded_df) == len(full_df)
# Out:
# True

# %%
encoded_df.columns
# Out:
# Index(['Purchase Date', 'Purchase Time', 'Payment_Method', 'Amount', 'Verification Date', 'First_Word', 'Last_Word', 'Category', 'VD_year', 'PT_total_seconds', 'sin_PT_total_seconds', 'cos_PT_total_seconds', 'PD_year', 'sin_PD_month', 'cos_PD_month', 'sin_PD_day', 'cos_PD_day', 'sin_VD_month', 'cos_VD_month', 'sin_VD_day', 'cos_VD_day', 'Payment_Method_Cat', 0, 1, 2, 3, 'Category_Cat', 'First_Word_Cat'], dtype='object')

# %%
full_df.columns
# Out:
# Index(['Purchase Date', 'Purchase Time', 'Payment_Method', 'Content', 'Amount', 'Verification Date', 'Category', 'Content_Word_Length', 'First_Word', 'Last_Word', 'Middle_Words'], dtype='object')

# %%
encoded_df[['Purchase Date', 'Purchase Time', 'Payment_Method', 'Amount',\
            'Verification Date', 'First_Word', 'Last_Word', 'Category', ]].compare(\
            full_df[['Purchase Date', 'Purchase Time', 'Payment_Method', 'Amount',\
         'Verification Date', 'First_Word', 'Last_Word', 'Category']], keep_shape = False)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
encoded_df[['Purchase Date', 'Purchase Time', 'Payment_Method', 'Amount',\
            'Verification Date', 'First_Word', 'Last_Word', 'Category', ]].equals(\
            full_df[['Purchase Date', 'Purchase Time', 'Payment_Method', 'Amount',\
         'Verification Date', 'First_Word', 'Last_Word', 'Category']])
# purchase times are different
# Out:
# True

# %%
type(full_df['Purchase Time'][0]) == type(full_df['Purchase Time'][0])
# Out:
# True

# %%
full_df[['Purchase Date', 'Purchase Time', 'Payment_Method', 'Amount',\
         'Verification Date', 'First_Word', 'Last_Word', 'Category']]
# Out:
#     Purchase Date Purchase Time         Payment_Method   Amount Verification Date                 First_Word Last_Word                  Category
# 0      2021-01-29      00:00:00                  Other  -187.68        2021-01-29                       USAA   Default            USAA Insurance
# 1      2021-01-27      00:00:00                  VENMO   669.80        2021-01-27        VENMO/CASHOUTWALTER   Default               Venmo Extra
# 2      2021-01-21      00:00:00                  Other  2099.81        2021-01-21                  Accenture         J                 Pay Check
# 3      2021-01-20      00:00:00                  VENMO  -845.00        2021-01-20        VENMO/PAYMENTWALTER   Default                      Rent
# 4      2021-01-20      00:00:00                  VENMO   -48.22        2021-01-20        VENMO/PAYMENTWALTER   Default                 Utilities
# ...

# %%
encoded_df['Content'] = full_df['Content'].copy()

# %%
encoded_df.columns
# Out:
# Index(['Purchase Date', 'Purchase Time', 'Payment_Method', 'Amount', 'Verification Date', 'First_Word', 'Last_Word', 'Category', 'VD_year', 'PT_total_seconds', 'sin_PT_total_seconds', 'cos_PT_total_seconds', 'PD_year', 'sin_PD_month', 'cos_PD_month', 'sin_PD_day', 'cos_PD_day', 'sin_VD_month', 'cos_VD_month', 'sin_VD_day', 'cos_VD_day', 'Payment_Method_Cat', 0, 1, 2, 3, 'Category_Cat', 'First_Word_Cat', 'Content'], dtype='object')

# %%
encoded_df = encoded_df[['Purchase Date', 'Purchase Time', 'Payment_Method', 'Amount', 'Verification Date','Content', 'First_Word',\
            'Last_Word', 'Category', 'VD_year', 'PT_total_seconds', 'sin_PT_total_seconds', 'cos_PT_total_seconds',\
            'PD_year', 'sin_PD_month', 'cos_PD_month', 'sin_PD_day', 'cos_PD_day', 'sin_VD_month', 'cos_VD_month',\
            'sin_VD_day', 'cos_VD_day', 'Payment_Method_Cat', 0, 1, 2, 3, 'Category_Cat', 'First_Word_Cat',\
            ]].copy()

# %%
encoded_df['Content'][724] #= encoded_df['Content'][724][1:]
# Out:
# 'PIZZA IAD STERLING VA 027220'

# %%
encoded_df.loc[724,'First_Word'] = encoded_df['Content'].apply(lambda x: x.split(' ')[0]).loc[724]

# %%
encoded_df['Content'].apply(lambda x: x.split(' ')[0]).loc[724]
# Out:
# 'PIZZA'

# %%
encoded_df['Last_Word'][724]
# Out:
# '027220'

# %%
encoded_df['Content'].apply(lambda x: x.split(' ')[0]).compare(encoded_df['First_Word'], keep_shape=False)
# Out:
# Empty DataFrame
# Columns: [self, other]
# Index: []

# %%
encoded_df.to_excel('fully_catized_encoded_2.xlsx',index=False)

# %%
pd.read_excel('fully_catized_encoded_2.xlsx')
# Out:
#     Purchase Date Purchase Time         Payment_Method   Amount Verification Date                                                              Content                 First_Word Last_Word                  Category  VD_year  ...  cos_VD_month    sin_VD_day  cos_VD_day  Payment_Method_Cat  0  1  2  3  Category_Cat  First_Word_Cat
# 0      2021-01-29      00:00:00                  Other  -187.68        2021-01-29                                USAA PC/PAYMENTWALTER COLEMAN Default                       USAA   Default            USAA Insurance     2021  ...  8.660254e-01 -3.943559e-01    0.918958                   0  1  0  0  0            14             143
# 1      2021-01-27      00:00:00                  VENMO   669.80        2021-01-27                                  VENMO/CASHOUTWALTER COLEMAN Default        VENMO/CASHOUTWALTER   Default               Venmo Extra     2021  ...  8.660254e-01 -7.247928e-01    0.688967                   3  0  0  0  1            16             148
# ...
