# %%
import pandas as pd
df = pd.read_csv('OctoberChecking.csv', 
                    usecols=['Transaction Number','Memo','Amount Debit','Amount Credit'],
                    skiprows=3)
df[['Amount Debit','Amount Credit']].fillna(0,inplace=True)
# oct_df[].fillna(0,inplace=True)
df['Memo'].fillna('Default',inplace=True)
df['Transaction Number'] = df['Transaction Number'].apply(lambda x: x.split('**')[1])
df['Memo'] = df['Memo'].apply(lambda x: x.split('*****')[0])
df['Content'] = df['Transaction Number'] + ' ' + df['Memo']
df['Amount'] = df['Amount Debit'].astype(float) + df['Amount Credit'].astype(float)
df['Category'] = 'Default'
df.drop(oct_df[df['Content'].str.contains("INTERNET TRANSFER",na=False)].index,inplace=True)
df.reset_index(drop=True,inplace=True)
df.drop(['Transaction Number','Memo','Amount Debit','Amount Credit'],
            axis=1,inplace=True)
pd.set_option('display.max_rows',None)
pd.set_option('display.max_rows',None)
pd.set_option('display.width', 1000)

# %%
# oct_df.columns = oct_df.loc[2]
# oct_df.drop([2],inplace=True)
#'Date','Balance','Check Number','Fees  ','Description'

# %%
oct_df
# Out:
#                                               Content   Amount Category
# 0   POS PURCHASE with PINCALIBER / COLLISION 1706 ...  -500.00  Default
# 1   POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...    -5.13  Default
# 2   POS PURCHASE / Non-PINAmazon.com*2T40W5IX2 Amz...   -31.10  Default
# 3   POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...   -47.56  Default
# 4   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...    -9.34  Default
# 5   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...    -9.78  Default
# 6   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...    -3.00  Default
# 7                 WASHINGTON GAS/PAYMENTEvan / Barnes   -81.96  Default
# 8             USAA PC/PAYMENTWALTER COLEMAN / Default  -187.68  Default
# 9   POS PURCHASE / Non-PINRAPPAHANNOCK COFFEE & R ...    -2.40  Default
# 10  POS PURCHASE with PINGIANT 0774 / ARLINGTON VA...   -52.51  Default
# 11            DOMINION ENERGY/BILLPAYWALTER / COLEMAN   -59.55  Default
# ...

# %%
df = oct_df.copy()

# %%
df[df['Content'].str.contains("UBER EATS",na=False)]['Category']
# Out:
# 2                                             Content  Amount Category
# 13  POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM ...   -3.50  Default
# 15  POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM ...  -17.51  Default
# 19  POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM ...  -21.32  Default
# 24  POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM ...  -18.51  Default
# 27  POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM ...  -23.08  Default
# 34  POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM ...  -17.01  Default
# 41  POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM ...  -25.64  Default

# %%
df[df['Content'].str.contains("UBER EATS",na=False)]['Category'] = 'Dining Out'
df[df['Content'].str.contains("HARRIS",na=False)]['Category'] = 'Groceries'
df[df['Content'].str.contains("GIANT",na=False)]['Category'] = 'Groceries'
df[df['Content'].str.contains("USAA",na=False)]['Category'] = 'USAA Insurance'
df[df['Content'].str.contains("Accenture",na=False)]['Category'] = 'Pay Check'
# Out:
# <ipython-input-4-093625182837>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Content'].str.contains("UBER EATS",na=False)]['Category'] = 'Dining Out'
# <ipython-input-4-093625182837>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df['Content'].str.contains("HARRIS",na=False)]['Category'] = 'Groceries'
# <ipython-input-4-093625182837>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df['Category']
# Out:
# 0     Default
# 1     Default
# 2     Default
# 3     Default
# 4     Default
# 5     Default
# 6     Default
# 7     Default
# 8     Default
# 9     Default
# 10    Default
# 11    Default
# 12    Default
# 13    Default
# 14    Default
# 15    Default
# 16    Default
# 17    Default
# 18    Default
# 19    Default
# 20    Default
# 21    Default
# 22    Default
# 23    Default
# 24    Default
# 25    Default
# 26    Default
# 27    Default
# 28    Default
# 29    Default
# 30    Default
# 31    Default
# 32    Default
# 33    Default
# 34    Default
# 35    Default
# 36    Default
# 37    Default
# 38    Default
# 39    Default
# 40    Default
# 41    Default
# 42    Default
# 43    Default
# 44    Default
# 45    Default
# 46    Default
# 47    Default
# 48    Default
# 49    Default
# 50    Default
# 51    Default
# 52    Default
# 53    Default
# 54    Default
# 55    Default
# 56    Default
# 57    Default
# 58    Default
# 59    Default
# 60    Default
# 61    Default
# ...

# %%
df.loc[df['Content'].str.contains("UBER EATS",na=False),'Category'] = 'Dining Out'
df.loc[df['Content'].str.contains("HARRIS",na=False),'Category'] = 'Groceries'
df.loc[df['Content'].str.contains("GIANT",na=False),'Category'] = 'Groceries'
df.loc[df['Content'].str.contains("USAA",na=False),'Category'] = 'USAA Insurance'
df.loc[df['Content'].str.contains("Accenture",na=False),'Category'] = 'Pay Check'

# %%
df['Category']
# Out:
# 0            Default
# 1          Groceries
# 2            Default
# 3          Groceries
# 4            Default
# 5            Default
# 6            Default
# 7            Default
# 8     USAA Insurance
# 9            Default
# 10         Groceries
# 11           Default
# 12           Default
# 13        Dining Out
# 14           Default
# 15        Dining Out
# 16           Default
# 17           Default
# 18           Default
# 19        Dining Out
# 20         Groceries
# 21         Groceries
# 22           Default
# 23           Default
# 24        Dining Out
# 25           Default
# 26           Default
# 27        Dining Out
# 28         Pay Check
# 29           Default
# 30           Default
# 31           Default
# 32           Default
# 33         Groceries
# 34        Dining Out
# 35           Default
# 36         Groceries
# 37           Default
# 38           Default
# 39           Default
# 40           Default
# 41        Dining Out
# 42           Default
# ...

# %%
df.loc[df['Content'].str.contains('Non-PIN',na=False)]
# Out:
# 2                                             Content  Amount    Category
# 2   POS PURCHASE / Non-PINAmazon.com*2T40W5IX2 Amz...  -31.10     Default
# 4   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -9.34     Default
# 5   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -9.78     Default
# 6   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -3.00     Default
# 9   POS PURCHASE / Non-PINRAPPAHANNOCK COFFEE & R ...   -2.40     Default
# 12  POS PURCHASE Non-PINMCDONALD'S / F20860 WASHIN...   -8.34     Default
# 13  POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM ...   -3.50  Dining Out
# 14  POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...  -11.80     Default
# 15  POS PURCHASE Non-PINUBER EATS / HELP.UBER.COM ...  -17.51  Dining Out
# 16  POS PURCHASE Non-PINMUSEUM OF / THE BIBLE WASH...  -10.59     Default
# 17  POS PURCHASE Non-PINPAYPAL *ETS / GRE 402-935-... -205.00     Default
# 18  POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -9.70     Default
# ...

# %%
df.loc[(df['Content'].str.contains('Non-PIN',na=False)) & (df['Category'] == 'Default')]
# Out:
# 2                                             Content  Amount Category
# 2   POS PURCHASE / Non-PINAmazon.com*2T40W5IX2 Amz...  -31.10  Default
# 4   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -9.34  Default
# 5   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -9.78  Default
# 6   POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -3.00  Default
# 9   POS PURCHASE / Non-PINRAPPAHANNOCK COFFEE & R ...   -2.40  Default
# 12  POS PURCHASE Non-PINMCDONALD'S / F20860 WASHIN...   -8.34  Default
# 14  POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...  -11.80  Default
# 16  POS PURCHASE Non-PINMUSEUM OF / THE BIBLE WASH...  -10.59  Default
# 17  POS PURCHASE Non-PINPAYPAL *ETS / GRE 402-935-... -205.00  Default
# 18  POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...   -9.70  Default
# 23  POS PURCHASE Non-PINTortas y / Tacos La Chiqu ...  -12.55  Default
# 29  POS PURCHASE Non-PINTAJ OF / INDIA ARLINGTON V...  -20.60  Default
# ...

# %%
df.loc[(df['Content'].str.contains('Non-PIN',na=False)) & (df['Category'] == 'Default'),'Content']
# Out:
# 2     POS PURCHASE / Non-PINAmazon.com*2T40W5IX2 Amz...
# 4     POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...
# 5     POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...
# 6     POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...
# 9     POS PURCHASE / Non-PINRAPPAHANNOCK COFFEE & R ...
# 12    POS PURCHASE Non-PINMCDONALD'S / F20860 WASHIN...
# 14    POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...
# 16    POS PURCHASE Non-PINMUSEUM OF / THE BIBLE WASH...
# 17    POS PURCHASE Non-PINPAYPAL *ETS / GRE 402-935-...
# 18    POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM ...
# 23    POS PURCHASE Non-PINTortas y / Tacos La Chiqu ...
# 29    POS PURCHASE Non-PINTAJ OF / INDIA ARLINGTON V...
# 30    POS PURCHASE Non-PINCOLONIAL / PARKING #648 AR...
# 31    POS PURCHASE Non-PINPP*GOOGLE A / MEDIUM CORP ...
# 32    POS PURCHASE Non-PINNAZRET / RESTAURANT 703-34...
# 35    POS PURCHASE Non-PINDISTRICT / MARTIAL ARTS 85...
# 38    POS PURCHASE Non-PINNAZRET / RESTAURANT 703-34...
# ...

# %%
df.loc[(df['Content'].str.contains('Non-PIN',na=False)) & (df['Category'] == 'Default'),'Content'].value_counts()
# Out:
# POS PURCHASE Non-PINNAZRET / RESTAURANT 703-3479911 VA768720             2
# POS PURCHASE Non-PINCORADOS / RESTAURANT WASHINGTON DC090207             2
# POS PURCHASE Non-PINNORTH / STREET PRESS CLUB FARMVILLE VA028407         1
# POS PURCHASE Non-PINDISTRICT / MARTIAL ARTS 859-421-1502 VAIN0700        1
# POS PURCHASE Non-PINTAJ OF / INDIA ARLINGTON VA IN1200                   1
# POS PURCHASE / Non-PINAmazon.com*2T40W5IX2 Amzn.com/bill WAINB900        1
# POS PURCHASE Non-PINSHELL / SERVICE STATION BOYCE VA820645               1
# POS PURCHASE Non-PINITALIAN / STATION FREDERICKSBUR VA760726             1
# POS PURCHASE Non-PINPAYPAL *ETS / GRE 402-935-7733 NJIN4400              1
# POS PURCHASE Non-PINUBER TRIP / HELP.UBER.COM CA IN9200                  1
# POS PURCHASE Non-PINUSA*VEND AT / AIR SERV FARMVILLE VAIN0700            1
# POS PURCHASE Non-PINCOLONIAL / PARKING #648 ARLINGTON VA000154           1
# ...

# %%
import pandas as pd
oct_df = pd.read_csv('OctoberChecking.csv', 
                     #usecols=['Transaction Number','Memo','Amount Debit','Amount Credit'],
                    skiprows=3)

# %%
oct_df
# Out:
#                                    Transaction Number        Date                       Description                                               Memo  Amount Debit  Amount Credit  Balance  Check Number  Fees
# 0   20201030000000[-5:EST]*-500.00*13**POS PURCHAS...  10/30/2020      POS PURCHASE with PINCALIBER  COLLISION 1706 ARLINGTON VA088816 *****1574 10...       -500.00            NaN   208.05           NaN     NaN
# 1   20201030000000[-5:EST]*-5.13*13**POS PURCHASE ...  10/30/2020   POS PURCHASE with PINGIANT 0774              ARLINGTON VA 001*****1574 10/29 19:18         -5.13            NaN   708.05           NaN     NaN
# 2      20201029000000[-5:EST]*-31.10*42**POS PURCHASE  10/29/2020                      POS PURCHASE  Non-PINAmazon.com*2T40W5IX2 Amzn.com/bill WAIN...        -31.10            NaN   713.18           NaN     NaN
# ...

# %%
oct_df.columns = oct_df.loc[2]
oct_df.drop([2],inplace=True)

# %%
oct_df
# Out:
# 2  20201030000000[-5:EST]*-5.13*13**POS PURCHASE with PINGIANT 0774  10/30/2020   POS PURCHASE with PINGIANT 0774              ARLINGTON VA 001*****1574 10/29 19:18         -5.13            NaN   708.05           NaN     NaN
# 0                                  Transaction Number                      Date                       Description                                               Memo  Amount Debit  Amount Credit  Balance  Check Number  Fees
# 1   20201030000000[-5:EST]*-500.00*13**POS PURCHAS...                10/30/2020      POS PURCHASE with PINCALIBER  COLLISION 1706 ARLINGTON VA088816 *****1574 10...          -500            NaN   208.05           NaN     NaN
# 3      20201029000000[-5:EST]*-31.10*42**POS PURCHASE                10/29/2020                      POS PURCHASE  Non-PINAmazon.com*2T40W5IX2 Amzn.com/bill WAIN...         -31.1            NaN   713.18           NaN     NaN
# ...

# %%
import pandas as pd
oct_df = pd.read_csv('OctoberChecking.csv')

# %%
oct_df
# Out:
#                           Account Name : Fox Checking  Unnamed: 1                        Unnamed: 2                                         Unnamed: 3    Unnamed: 4     Unnamed: 5 Unnamed: 6    Unnamed: 7 Unnamed: 8
# 0                 Account Number : 229753847K63032206         NaN                               NaN                                                NaN           NaN            NaN        NaN           NaN        NaN
# 1                  Date Range : 10/01/2020-10/31/2020         NaN                               NaN                                                NaN           NaN            NaN        NaN           NaN        NaN
# 2                                  Transaction Number        Date                       Description                                               Memo  Amount Debit  Amount Credit    Balance  Check Number     Fees
# ...

# %%
import pandas as pd
oct_df = pd.read_csv('OctoberChecking.csv', 
                    usecols=['Memo'],
                    skiprows=3)

# %%
import pandas as pd
oct_df = pd.read_csv('OctoberChecking.csv', 
                    usecols=['Transaction Number','Memo','Amount Debit','Amount Credit'],
                    skiprows=3)

# %%
oct_df
# Out:
#                                    Transaction Number                                               Memo  Amount Debit  Amount Credit
# 0   20201030000000[-5:EST]*-500.00*13**POS PURCHAS...  COLLISION 1706 ARLINGTON VA088816 *****1574 10...       -500.00            NaN
# 1   20201030000000[-5:EST]*-5.13*13**POS PURCHASE ...              ARLINGTON VA 001*****1574 10/29 19:18         -5.13            NaN
# 2      20201029000000[-5:EST]*-31.10*42**POS PURCHASE  Non-PINAmazon.com*2T40W5IX2 Amzn.com/bill WAIN...        -31.10            NaN
# 3   20201029000000[-5:EST]*-47.56*13**POS PURCHASE...              ARLINGTON VA 001*****1574 10/28 19:21        -47.56            NaN
# 4   20201028000000[-5:EST]*-9.34*42**POS PURCHASE ...       HELP.UBER.COM CA IN0002*****1574 10/28 06:00         -9.34            NaN
# 5   20201028000000[-5:EST]*-9.78*42**POS PURCHASE ...       HELP.UBER.COM CA INA500*****1574 10/28 06:00         -9.78            NaN
# ...
